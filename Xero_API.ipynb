# %%
# !pip install selenium
# Selenium requires a driver to interface with the chosen browser. 
# Chrome driver https://sites.google.com/a/chromium.org/chromedriver/downloads

# %% [markdown]
# ## Setup
# https://developer.xero.com/documentation/oauth2/auth-flow

# %%
#setup client_id (application id)
client_id = ''
#setup client_secret (application secret)
client_secret = '' 
#setup redirect_url (application redirect url)
redirect_url = 'https://xero.com/'
#setup scope to access, whole list - https://developer.xero.com/documentation/oauth2/scopes
scope_list = ['offline_access', 
              'accounting.transactions.read', 'accounting.journals.read', 'accounting.settings.read', 
              'payroll.employees.read','payroll.payruns.read', 'payroll.payslip.read','assets.read']

# %%
import json
import requests
from selenium import webdriver
#import webbrowser
import base64
import pandas as pd
import datetime
import time
import os
import getpass
import keyring

assert client_id, 'client_id is empty'
assert client_secret, 'client_secret is empty'
assert redirect_url, 'redirect_url is empty'

scope = ' '.join(scope_list)

b64_id_secret = base64.b64encode(bytes(client_id + ':' + client_secret, 'utf-8')).decode('utf-8')

def FirstAuth():
    # Send a user to authorize your app
    auth_url = ('''https://login.xero.com/identity/connect/authorize?''' +
                '''response_type=code''' +
                '''&client_id=''' + client_id +
                '''&redirect_uri=''' + redirect_url +
                '''&scope=''' + scope)
    #####################################################
    # - Interaction required
    #webbrowser.open_new(auth_url)  
    # Users are redirected back with a code  
    #print()
    #auth_res_url = input('What is the response URL? ')
    ####################################################
    
    #####################################################
    # + Without Interaction      
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument("--incognito")
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(auth_url)
    auth_res_url = auth_url
    #waiting while there will be "code" in the browser's URL
    while auth_res_url.find('code=') == -1:
        time.sleep(1) # 1 second sleep
        auth_res_url = driver.current_url        
  ######################################################  
    
    start_number = auth_res_url.find('code=') + len('code=')
    end_number = auth_res_url.find('&scope')
    auth_code = auth_res_url[start_number:end_number]
    #print(auth_code+'\n')
    
    # Exchange the code
    exchange_code_url = 'https://identity.xero.com/connect/token'
    response = requests.post(exchange_code_url, 
                            headers = {
                                'Authorization': 'Basic ' + b64_id_secret
                            },
                            data = {
                                'grant_type': 'authorization_code',
                                'code': auth_code,
                                'redirect_uri': redirect_url
                            })
    json_response = response.json()
    #print(json_response + '\n')
     
    # Return the tokens
    return {'access' : json_response['access_token'], 'refresh' : json_response['refresh_token']}


# Check the full set of tenants that user have been authorized to access
def GetTenants(access_token):
    connections_url = 'https://api.xero.com/connections'
    response = requests.get(connections_url,
                           headers = {
                               'Authorization': 'Bearer ' + access_token,
                               'Content-Type': 'application/json'
                           })
    json_response = response.json()
    
    #print(json_response)

    return([tenants['tenantId'] for tenants in json_response])

# Refreshing access tokens
def RefreshTokens(refresh_token):
    token_refresh_url = 'https://identity.xero.com/connect/token'
    response = requests.post(token_refresh_url,
                            headers = {
                                'Authorization' : 'Basic ' + b64_id_secret,
                                'Content-Type': 'application/x-www-form-urlencoded'
                            },
                            data = {
                                'grant_type' : 'refresh_token',
                                'refresh_token' : refresh_token
                            })
    json_response = response.json()
    #print(json_response)
    
    keyring.set_password('refresh_token', getpass.getuser(), json_response['refresh_token'])
    keyring.set_password('refresh_token_date', getpass.getuser(), str(datetime.datetime.now().timestamp()))
    
    return {'access' : json_response['access_token'], 'refresh' : json_response['refresh_token']}

# Data API
def GetData(api_url, tokens, tenant_id=''):
  
    if tenant_id == '':    
        tenant_id = XeroTenants(tokens['access'])[0]#very first tenant
   
    #print('xero_tenant_id = ' + xero_tenant_id)
     
    #https://developer.xero.com/documentation/oauth2/auth-flow
    data_type = api_url[api_url.rfind('/')+1:]
    last_page = False
    page = 1
    ret = list()
    while not last_page: 
        response = requests.get(api_url+'?page='+str(page),
                               headers = {
                                   'Authorization': 'Bearer ' + tokens['access'],
                                   'Xero-tenant-id': tenant_id,
                                   'Accept': 'application/json'
                               })
       
        #print(response)
        
        if response.status_code!=200:
            print('Bad server response for \'{}\' : {}'.format(data_type, response))
            if response.status_code not in (401, 403, 404):
                print('Retrieved JSON:\n{}'.format(response.json()))
            return ret;    
        else:
            json_response = response.json()
           
            data_response = json_response[data_type]

            ret = ret + data_response

            if len(data_response) < 100:
                last_page=True
            else:
                page+=1
        
        
    return ret

# %%
Accounts_URL = 'https://api.xero.com/api.xro/2.0/Accounts'
BankTransactions_URL = 'https://api.xero.com/api.xro/2.0/BankTransactions'
TrackingCategories_URL = 'https://api.xero.com/api.xro/2.0/TrackingCategories'
Invoices_URL = 'https://api.xero.com/api.xro/2.0/Invoices'
Users_URL = 'https://api.xero.com/api.xro/2.0/Users'
Employees_URL = 'https://api.xero.com/api.xro/2.0/Employees'

refresh_token_age = -1
tokens = dict()

token_date = keyring.get_password('refresh_token_date', getpass.getuser())

if token_date is not None:
    token_date = datetime.datetime.fromtimestamp(int(float(token_date)))
    #print('refresh_token_date = {}'.format(token_date))
    current_date = datetime.datetime.now() 
    refresh_token_age = (current_date - token_date).seconds/3600
    #print('refresh_token_age = {}'.format(refresh_token_age))
    
if (refresh_token_age < 0) | (refresh_token_age > 59):    
    tokens = FirstAuth()
else:
    tokens = {'refresh' : keyring.get_password("refresh_token", getpass.getuser())}

tokens = RefreshTokens(tokens['refresh'])
tenant_id = GetTenants(tokens['access'])[0]

# Get Data

df_accounts = pd.DataFrame(GetData(Accounts_URL, tokens, tenant_id))

df_bank_transactions = pd.DataFrame(GetData(BankTransactions_URL, tokens, tenant_id))

df_tracking_categories = pd.DataFrame(GetData(TrackingCategories_URL, tokens, tenant_id))

df_invoices = pd.DataFrame(GetData(Invoices_URL, tokens, tenant_id))

df_users = pd.DataFrame(GetData(Users_URL, tokens, tenant_id))

df_employees = pd.DataFrame(GetData(Employees_URL, tokens, tenant_id))

# %%
df_accounts
# Out:
#                                AccountID Code                      Name  \
# 0   ac993f75-035b-433c-82e0-7b7a2d40802c  090     Business Bank Account
# 1   ebd06280-af70-4bed-97c6-7451a454ad85  091  Business Savings Account
# 2   7d05a53d-613d-4eb2-a2fc-dcb6adb80b80  200                     Sales
# 3   ba3f61ed-2992-4468-bd4d-fd3ee2cb16c9  260             Other Revenue
# 4   32865dbc-8b1e-4a76-8f5c-3579cbb3520b  270           Interest Income
# ..                                   ...  ...                       ...
# 57  d08883ef-50e9-4ae4-b9d3-a5c4984658a2  877        Tracking Transfers
# 58  641b46db-2b69-4cb2-be3d-610ee7e2217f  900                      Loan
# 59  4f4528dd-c8a3-4e31-8a45-e2e4221de791  960         Retained Earnings
# 60  f409f07f-c72d-4478-b188-8563deb9e1a6  970  Owner A Funds Introduced
# 61  62bc989b-fae6-45f0-8440-a3d7308f1d4f  980          Owner A Drawings
#
#     Status      Type  TaxType      Class  EnablePaymentsToAccount  \
# 0   ACTIVE      BANK     NONE      ASSET                    False
# 1   ACTIVE      BANK     NONE      ASSET                    False
# 2   ACTIVE   REVENUE  OUTPUT2    REVENUE                    False
# 3   ACTIVE   REVENUE  OUTPUT2    REVENUE                    False
# 4   ACTIVE   REVENUE     NONE    REVENUE                    False
# ..     ...       ...      ...        ...                      ...
# 57  ACTIVE  CURRLIAB     NONE  LIABILITY                    False
# 58  ACTIVE  TERMLIAB     NONE  LIABILITY                    False
# 59  ACTIVE    EQUITY     NONE     EQUITY                    False
# 60  ACTIVE    EQUITY     NONE     EQUITY                     True
# 61  ACTIVE    EQUITY     NONE     EQUITY                     True
#
#     ShowInExpenseClaims BankAccountNumber BankAccountType CurrencyCode  \
# 0                 False  1201020345678000            BANK          NZD
# 1                 False  0209087654321050            BANK          NZD
# 2                 False               NaN                          NaN
# 3                 False               NaN                          NaN
# 4                 False               NaN                          NaN
# ..                  ...               ...             ...          ...
# 57                False               NaN                          NaN
# 58                False               NaN                          NaN
# 59                False               NaN                          NaN
# 60                False               NaN                          NaN
# 61                False               NaN                          NaN
#
#    ReportingCode                        ReportingCodeName  HasAttachments  \
# 0            ASS                                   Assets           False
# 1            ASS                                   Assets           False
# 2        REV.TRA                          Trading revenue           False
# 3        REV.OTH                            Other revenue           False
# 4    REV.INV.INT                                 Interest           False
# ..           ...                                      ...             ...
# 57       LIA.CUR                      Current Liabilities           False
# 58   LIA.NCL.LOA                                    Loans           False
# 59       EQU.RET      Retained earnings/Accumulated funds           False
# 60   LIA.NCL.ADV  Proprietor/shareholder advance accounts           False
# 61   LIA.NCL.ADV  Proprietor/shareholder advance accounts           False
#
#                 UpdatedDateUTC  AddToWatchlist  \
# 0   /Date(1602989731783+0000)/           False
# 1   /Date(1602989731783+0000)/           False
# 2   /Date(1602989731783+0000)/            True
# 3   /Date(1602989731783+0000)/           False
# 4   /Date(1602989731783+0000)/           False
# ..                         ...             ...
# 57  /Date(1602989731783+0000)/           False
# 58  /Date(1602989731783+0000)/           False
# 59  /Date(1602989731783+0000)/           False
# 60  /Date(1602989731783+0000)/           False
# 61  /Date(1602989731783+0000)/           False
#
#                                           Description      SystemAccount
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2            Income from any normal business activity
# 3   Any other income that does not relate to norma...
# 4   Gross interest income (i.e. before deducting R...
# ..                                                ...                ...
# 57              Transfers between tracking categories  TRACKINGTRANSFERS
# 58       Money that has been borrowed from a creditor
# 59                                         Do not Use   RETAINEDEARNINGS
# 60                     Funds contributed by the owner
# 61                          Withdrawals by the owners
#
# [62 rows x 19 columns]

# %%
df_bank_transactions
# Out:
#                        BankTransactionID  \
# 0   63d47b99-e1ef-4b46-84db-034f2205f8fb
# 1   303aa035-16dd-45f1-9710-310dc654a7c9
# 2   1e1eaf36-cb33-4914-9c23-78dac6508f04
# 3   10b4de96-eefa-4dae-9eb8-d611081c97d0
# 4   8b043e8b-2df2-41ce-b5a7-437f2851376f
# 5   cbd5def7-d950-4fd9-affa-e9e0fa3753ff
# 6   140cf65f-062e-4616-9a94-9eb066e3f601
# 7   5970fa02-c8a6-412f-ac86-cee98c2d4438
# 8   e6248e6d-1daf-425f-95fe-5c5f273ff6b1
# 9   02ec32ad-fc69-464d-9655-f04b1f0a50f8
# 10  e198a42a-6168-4523-9e70-f281d9b52574
# 11  d5d0150e-8be6-4847-88da-302876718753
# 12  fbf45b40-1a92-4eff-9e0d-4d6e205e4a3b
# 13  96523e70-9fca-43ce-8c98-881277db01c8
# 14  ddea633d-2f8a-49ee-8b7b-3994ce42f7b8
#
#                                           BankAccount     Type   Reference  \
# 0   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND  Sub 098801
# 1   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...  RECEIVE  Sub 098801
# 2   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND         Fee
# 3   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND         Eft
# 4   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND
# 5   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND
# 6   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND        Gift
# 7   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND
# 8   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND     Chq 409
# 9   {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND         Fee
# 10  {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND     Chq 410
# 11  {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND         Eft
# 12  {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND     Chq 411
# 13  {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND         Eft
# 14  {'AccountID': 'ac993f75-035b-433c-82e0-7b7a2d4...    SPEND
#
#     IsReconciled  HasAttachments  \
# 0          False           False
# 1          False           False
# 2           True           False
# 3           True           False
# 4           True           False
# 5           True           False
# 6           True           False
# 7           True           False
# 8           True           False
# 9           True           False
# 10          True           False
# 11          True           False
# 12          True           False
# 13          True           False
# 14          True           False
#
#                                               Contact           DateString  \
# 0   {'ContactID': '6d42f03b-181f-43e3-93fb-2025c01...  2020-10-14T00:00:00
# 1   {'ContactID': '6d42f03b-181f-43e3-93fb-2025c01...  2020-10-16T00:00:00
# 2   {'ContactID': '2b6d2035-ded0-45a7-b2ad-4b01c78...  2020-07-23T00:00:00
# 3   {'ContactID': '873c07a8-511a-420d-a664-a01a508...  2020-07-28T00:00:00
# 4   {'ContactID': 'c37099f9-b207-4c0a-84de-a635eea...  2020-07-30T00:00:00
# 5   {'ContactID': '2a7f9bc5-d0fe-40bf-834d-6c7be44...  2020-08-02T00:00:00
# 6   {'ContactID': 'ae136984-5d9a-4025-a045-bf4dc42...  2020-08-06T00:00:00
# 7   {'ContactID': 'baf81bcb-eebf-4b8a-977d-95b11f5...  2020-08-09T00:00:00
# 8   {'ContactID': '8c555bc8-8098-43cd-bfa1-acd5573...  2020-08-09T00:00:00
# 9   {'ContactID': '2b6d2035-ded0-45a7-b2ad-4b01c78...  2020-08-22T00:00:00
# 10  {'ContactID': '8c555bc8-8098-43cd-bfa1-acd5573...  2020-09-08T00:00:00
# 11  {'ContactID': '2a7f9bc5-d0fe-40bf-834d-6c7be44...  2020-09-12T00:00:00
# 12  {'ContactID': 'f1d403d1-7d30-46c2-a2be-fc2bb29...  2020-09-26T00:00:00
# 13  {'ContactID': '873c07a8-511a-420d-a664-a01a508...  2020-09-24T00:00:00
# 14  {'ContactID': 'baf81bcb-eebf-4b8a-977d-95b11f5...  2020-09-26T00:00:00
#
#                           Date      Status LineAmountTypes  \
# 0   /Date(1602633600000+0000)/  AUTHORISED       Inclusive
# 1   /Date(1602806400000+0000)/  AUTHORISED       Inclusive
# 2   /Date(1595462400000+0000)/  AUTHORISED       Inclusive
# 3   /Date(1595894400000+0000)/  AUTHORISED       Inclusive
# 4   /Date(1596067200000+0000)/  AUTHORISED       Inclusive
# 5   /Date(1596326400000+0000)/  AUTHORISED       Inclusive
# 6   /Date(1596672000000+0000)/  AUTHORISED       Inclusive
# 7   /Date(1596931200000+0000)/  AUTHORISED       Inclusive
# 8   /Date(1596931200000+0000)/  AUTHORISED       Inclusive
# 9   /Date(1598054400000+0000)/  AUTHORISED       Inclusive
# 10  /Date(1599523200000+0000)/  AUTHORISED       Inclusive
# 11  /Date(1599868800000+0000)/  AUTHORISED       Inclusive
# 12  /Date(1601078400000+0000)/  AUTHORISED       Inclusive
# 13  /Date(1600905600000+0000)/  AUTHORISED       Inclusive
# 14  /Date(1601078400000+0000)/  AUTHORISED       Inclusive
#
#                                             LineItems  SubTotal  TotalTax  \
# 0   [{'Description': 'Subscription', 'UnitAmount':...     43.39      6.51
# 1   [{'Description': 'Long-term subscriber discoun...     30.43      4.57
# 2   [{'Description': 'Bank fee', 'UnitAmount': 15....     15.00      0.00
# 3   [{'Description': 'Misc stationery', 'UnitAmoun...     18.88      2.83
# 4   [{'Description': 'Team coffees', 'UnitAmount':...     13.91      2.09
# 5   [{'Description': 'Misc kitchen supplies for of...     56.70      8.50
# 6   [{'Description': 'Bouquet for client', 'UnitAm...     43.48      6.52
# 7   [{'Description': 'Team coffee', 'UnitAmount': ...     13.57      2.03
# 8   [{'Description': 'Monthly carpark', 'UnitAmoun...    129.13     19.37
# 9   [{'Description': 'Bank fee', 'UnitAmount': 15....     15.00      0.00
# 10  [{'Description': 'Monthly carpark', 'UnitAmoun...    129.13     19.37
# 11  [{'Description': 'Misc kitchen supplies for of...     29.65      4.45
# 12  [{'Description': 'Emergency locksmith - front ...     60.43      9.07
# 13  [{'Description': 'Photocopier paper', 'UnitAmo...     42.78      6.42
# 14  [{'Description': 'Staff coffees', 'UnitAmount'...     19.13      2.87
#
#      Total              UpdatedDateUTC CurrencyCode
# 0    49.90  /Date(1290384000000+0000)/          NZD
# 1    35.00  /Date(1290556800000+0000)/          NZD
# 2    15.00  /Date(1290614258523+0000)/          NZD
# 3    21.71  /Date(1290614269007+0000)/          NZD
# 4    16.00  /Date(1290614270600+0000)/          NZD
# 5    65.20  /Date(1290614272347+0000)/          NZD
# 6    50.00  /Date(1290614277917+0000)/          NZD
# 7    15.60  /Date(1290614279787+0000)/          NZD
# 8   148.50  /Date(1290614291083+0000)/          NZD
# 9    15.00  /Date(1290804224810+0000)/          NZD
# 10  148.50  /Date(1291136613440+0000)/          NZD
# 11   34.10  /Date(1291136617637+0000)/          NZD
# 12   69.50  /Date(1291136679430+0000)/          NZD
# 13   49.20  /Date(1291136705907+0000)/          NZD
# 14   22.00  /Date(1291136710930+0000)/          NZD

# %%
df_tracking_categories
# Out:
#      Name  Status                    TrackingCategoryID  \
# 0  Region  ACTIVE  351953c4-8127-4009-88c3-f9cd8c9cbe9f
#
#                                              Options
# 0  [{'TrackingOptionID': 'ce205173-7387-4651-9726...

# %%
df_invoices
# Out:
#       Type                             InvoiceID InvoiceNumber     Reference  \
# 0   ACCPAY  22b3fab4-ef56-4d70-a110-a7cc3c1a26cd         Elec.
# 1   ACCPAY  96988e67-ecf9-466d-bfbf-0afa1725a649      RPT445-1
# 2   ACCPAY  6e65ea34-ccd7-49e7-b80a-b3feec4c1c48      RPT445-1
# 3   ACCPAY  33f11d54-2105-4041-b77b-9097578e7c9d      RPT445-1
# 4   ACCPAY  ac1fc284-2e69-46b6-95b3-17949c65bb42      RPT445-1
# ..     ...                                   ...           ...           ...
# 74  ACCREC  69a49503-69fb-4da0-9ac0-69e421c6e50c      INV-0034      P/O 9711
# 75  ACCREC  0be4a903-e493-4c3e-b001-6b68d23524f6      INV-0035  P/O CRM08-12
# 76  ACCREC  33a66615-d092-413a-bd80-54609f7a755d      INV-0028          Book
# 77  ACCREC  1fcc5819-1b6c-437b-b984-ae2e5c8ed46b      INV-0023      P/O 9711
# 78  ACCREC  98ec6044-ba2d-40b6-b836-b41e46f328e4      INV-0017      P/O 9711
#
#                                              Payments CreditNotes Prepayments  \
# 0                                                  []          []          []
# 1   [{'PaymentID': '0a0ef7ee-7b91-46fa-8136-c4cc62...          []          []
# 2   [{'PaymentID': '603b8347-d833-4e65-abf9-1f4656...          []          []
# 3   [{'PaymentID': '285d0c41-5e16-45d2-90b6-673c91...          []          []
# 4   [{'PaymentID': 'e41cab17-9785-45f2-88d4-6aad48...          []          []
# ..                                                ...         ...         ...
# 74                                                 []          []          []
# 75                                                 []          []          []
# 76                                                 []          []          []
# 77                                                 []          []          []
# 78                                                 []          []          []
#
#    Overpayments  AmountDue  AmountPaid  ...  \
# 0            []       0.00         0.0  ...
# 1            []       0.00        90.0  ...
# 2            []       0.00        95.5  ...
# 3            []       0.00        97.0  ...
# 4            []       0.00        92.0  ...
# ..          ...        ...         ...  ...
# 74           []     650.00         0.0  ...
# 75           []    6187.50         0.0  ...
# 76           []      19.95         0.0  ...
# 77           []     250.00         0.0  ...
# 78           []     250.00         0.0  ...
#
#                                             LineItems  SubTotal  TotalTax  \
# 0   [{'Description': 'Monthly electricity', 'UnitA...     77.39     11.61
# 1   [{'Description': 'Monthly electricity', 'UnitA...     78.26     11.74
# 2   [{'Description': 'Monthly electricity', 'UnitA...     83.04     12.46
# 3   [{'Description': 'Monthly electricity', 'UnitA...     84.35     12.65
# 4   [{'Description': 'Monthly electricity', 'UnitA...     80.00     12.00
# ..                                                ...       ...       ...
# 74  [{'Description': 'Development work - develper ...    565.22     84.78
# 75  [{'Description': 'Onsite project management fo...   5380.43    807.07
# 76  [{'ItemCode': 'BOOK', 'Description': ''Fish ou...     17.35      2.60
# 77  [{'ItemCode': 'PR-BR', 'Description': 'Project...    217.39     32.61
# 78  [{'ItemCode': 'PR-BR', 'Description': 'Project...    217.39     32.61
#
#       Total              UpdatedDateUTC CurrencyCode  \
# 0     89.00  /Date(1289566516347+0000)/          NZD
# 1     90.00  /Date(1289572094303+0000)/          NZD
# 2     95.50  /Date(1289572118670+0000)/          NZD
# 3     97.00  /Date(1289579146917+0000)/          NZD
# 4     92.00  /Date(1289579167027+0000)/          NZD
# ..      ...                         ...          ...
# 74   650.00  /Date(1466787093510+0000)/          NZD
# 75  6187.50  /Date(1466787115637+0000)/          NZD
# 76    19.95  /Date(1466787133887+0000)/          NZD
# 77   250.00  /Date(1466787170870+0000)/          NZD
# 78   250.00  /Date(1466787188930+0000)/          NZD
#
#                       RepeatingInvoiceID             FullyPaidOnDate  \
# 0                                    NaN                         NaN
# 1   ad3550bc-1ae0-45c0-a782-48c6d2061127  /Date(1569974400000+0000)/
# 2   ad3550bc-1ae0-45c0-a782-48c6d2061127  /Date(1572480000000+0000)/
# 3   ad3550bc-1ae0-45c0-a782-48c6d2061127  /Date(1574899200000+0000)/
# 4   ad3550bc-1ae0-45c0-a782-48c6d2061127  /Date(1577664000000+0000)/
# ..                                   ...                         ...
# 74                                   NaN                         NaN
# 75                                   NaN                         NaN
# 76                                   NaN                         NaN
# 77                                   NaN                         NaN
# 78                                   NaN                         NaN
#
#    SentToContact                       BrandingThemeID
# 0            NaN                                   NaN
# 1            NaN                                   NaN
# 2            NaN                                   NaN
# 3            NaN                                   NaN
# 4            NaN                                   NaN
# ..           ...                                   ...
# 74          True  7889a0ac-262a-40e3-8a63-9a769b1a18af
# 75          True  7889a0ac-262a-40e3-8a63-9a769b1a18af
# 76          True  7889a0ac-262a-40e3-8a63-9a769b1a18af
# 77          True  7889a0ac-262a-40e3-8a63-9a769b1a18af
# 78          True  7889a0ac-262a-40e3-8a63-9a769b1a18af
#
# [79 rows x 32 columns]

# %% [markdown]
# ### If case if needed to delete saved passwords

# %%
keyring.delete_password("refresh_token", getpass.getuser())
keyring.delete_password("refresh_token_date", getpass.getuser())
